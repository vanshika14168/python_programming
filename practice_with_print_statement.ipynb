# %% [markdown]
# <a href="https://colab.research.google.com/github/vanshika14168/python_programming/blob/main/practice_with_print_statement.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#print name, age,address using print statement
print("name is : vanshika")
print("age is:",20)
print("address :Indore")
# Out:
# name is : vanshika
# age is: 20
# address :Indore

# %%
#display loading without using newline in print
print("loading.......")
# Out:
# loading.......

# %%
#print the text Hi!"your name is having fun with python"
print("Hi!\" vanshika is having fun with python\"")
# Out:
# Hi!" vanshika is having fun with python"

# %%
#repate the message pyhton rocks! 5 times
print("python rocks!\n"*5)
# Out:
# python rocks!
# python rocks!
# python rocks!
# python rocks!
# python rocks!

# %%
#display this C:\USER\Vanshika\Document in python
print("C:\\USER\\Vanshika\\Document in python")
# Out:
# C:\USER\Vansshika\Document in python

# %%
#print Red-Green-Blue in proper format
print("Red",end="-")
print("Green",end="-")
print("Blue")
# Out:
# Red-Green-Blue

# %%
#print the following format:
#Name     Age
#Alice    20
#Bob      25
#\t is used for tab space so the column align properly
print("Name\tAge")
print("Alice\t20")
print("Bob\t25")
# Out:
# Name	Age
# Alice	20
# Bob	25
