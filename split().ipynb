# %% [markdown]
# <a href="https://colab.research.google.com/github/vanshika14168/python_programming/blob/main/split().ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#define split().give syntax with exaple
"""the split() method.split a string into a two list based on a specified seprator
syntax: string.split(seprator,maxspllit)"""

text="hello world from python"
print("before split:",text)
word=text.split()
print("after split:",word)
# Out:
# before split: hello world from python
# after split: ['hello', 'world', 'from', 'python']
