# %% [markdown]
# <a href="https://colab.research.google.com/github/vanshika14168/python_programming/blob/main/join().ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#define join with example
"""join() is a string method used to join the elements of an iterable(list,tuple,etc)
into one string using a specified separator
syntax: separator.join(iterable)"""

words=['I','am','from','data-science']
print("before join:",words)
result=" ".join(words)
print("after join:",result)
# Out:
# before join: ['I', 'am', 'from', 'data-science']
# after join: I am from data-science
